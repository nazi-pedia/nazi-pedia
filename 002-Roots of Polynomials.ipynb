# %% [markdown]
# $$ P(x)=x-5 $$

# %%
import sympy as sp
x = sp.symbols('x')
poly = x - 5
roots = sp.solve(poly, x)
print("Roots:", roots)
# Out:
# Roots: [5]

# %% [markdown]
# $$P(x)=x^2-5x+6$$

# %%
import sympy as sp

x = sp.symbols('x')

poly = x**2 - 5*x + 6

print(sp.factor(poly))

roots = sp.solve(poly, x)

print("Roots:", roots)
# Out:
# (x - 3)*(x - 2)
# Roots: [2, 3]

# %% [markdown]
# $$ P(x)=2x^2-7x+3 $$

# %%
import sympy as sp

x = sp.symbols('x')

poly = 2*x**2 - 7*x + 3

roots = sp.solve(poly, x)

print("Roots:", roots)
# Out:
# Roots: [1/2, 3]

# %% [markdown]
# $$ P(x)=2x^3-3x^2-11x+6$$

# %%
import numpy as np

coefficients = [2, -3, -11, 6]

roots = np.roots(coefficients)

print("Roots:", roots)
# Out:
# Roots: [ 3.  -2.   0.5]

# %% [markdown]
# $$ P(x)=x^2+4x+5$$

# %%
import sympy as sp

x = sp.symbols('x')

poly = x**2 + 4*x + 5

roots = sp.solve(poly, x)

print("Roots:", roots)
# Out:
# Roots: [-2 - I, -2 + I]
